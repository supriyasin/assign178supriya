# %%
#1. In the below elements which of them are values or an expression? eg:- values can be
integer or string and expressions will be mathematical operators.
*
'hello'
-87.8
-
/
+
6"""

"""#values = 'hello', -87.8, 6
   #expressions = *, -, /, +"""

#2. What is the difference between string and variable?

"""A string is traditionally a sequence of characters, either as a literal  constant or as some kind 
of variable. The latter may allow its elements to be mutated and the length changed, or it may be fixed(after creation).
A string is generally considered as a data type and is often implemented as an array data type and is often implemented
as an array data structure of bytes(or words) that stores a sequence of element, typically characters, using some 
character encoding. String may also denote more general arrays or other sequence(or list) data type and structures.

A variable is an abstract storage location paired with an associated symbolic name, wich contains some known or unknown 
quantity of information referred to as avalue; or in simpler terms, a variable is a named container for a particular
set of bits or type of data(like integer,float,string etc...). A variable can a memory address with or identified
by a memory address. The name is the usual way to refernce the stored value, in addition to referring to the variable
itself, depending on the context. This separation of name and content allows the name and content allows the name 
to be used indepndently of the exact information it represents. The identifier in computer sources code can be bound
to a value of the variable may thus change during the course of program excuation."""


#3. Describe three different data types.


"""Data type = Numeric, String, Sequence

Numeric Classes = int,float,complex
Numeric Description = hold numeric values

String Classes = str
String Description = hold sequence of characters

Sequence Classes = list,tuple,range
Sequence Descripition = hold collation of items"""

#4. What is an expression made up of? What do all expressions do? 

""" An experssion is a combination of values and operators. All expression evaluate
    (that is,reduse) to a single value."""

#5. This assignment statements, like spam = 10. What is the difference between an
expression and a statement?

"""Statement represent an action or command e.g print statement, or assignment statement. Expression is a combination
of variable, operation and values that yeield a result value."""

#6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1
"23"

#7. What should the values of the following two terms be?
'spam' + 'spamspam'
'spam' * 3

"""spam * 3 = spamspam"""

#8. Why is eggs a valid variable name while 100 is invalid?

"""Variable names cannot begin with a number"""


#9. What three functions can be used to get the integer, floating-point number, or string
version of a value?

"""The int(), float(), and str() fuctions will evaluate to the integer, floating-point number,
   and string version of the value passed to them."""

#10. Why does this expression cause an error? How can you fix it?
'I have eaten ''+ 99 + 'burritos'.

"""The expression causes an error because 99 is an integer, and only string can be concatenated
   to other string with the + operator. The correct ways is I have eaten '+ str(99) + 'burriots'."""
# Out:
#   Input In [1]
#     integer or string and expressions will be mathematical operators.
#                                       ^
# SyntaxError: invalid syntax
